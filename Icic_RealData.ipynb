# %%
# !pip install schedule

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import schedule
from datetime import time,timedelta,datetime
import time as tm

# %%
data_icici=yf.download(tickers='ICICIBANK.NS', period='7d', interval='15m',)
data_icici
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2023-11-02 09:15:00  921.150024  923.250000  920.200012  921.250000
# 2023-11-02 09:30:00  921.450012  924.599976  920.500000  923.650024
# 2023-11-02 09:45:00  923.599976  923.700012  921.099976  922.400024
# 2023-11-02 10:00:00  922.400024  923.099976  920.299988  920.849976
# 2023-11-02 10:15:00  920.849976  922.099976  920.250000  921.650024
# ...                         ...         ...         ...         ...
# 2023-11-10 14:15:00  936.849976  937.400024  935.400024  936.700012
# 2023-11-10 14:30:00  937.099976  938.200012  934.849976  936.849976
# 2023-11-10 14:45:00  936.700012  937.750000  936.099976  937.700012
# 2023-11-10 15:00:00  937.700012  939.750000  937.049988  938.500000
# 2023-11-10 15:15:00  938.500000  941.099976  937.400024  938.599976
#
#                       Adj Close  Volume
# Datetime
# ...

# %%
data_icici
# Out:
#                            Open        High         Low       Close  \
# Datetime
# 2023-11-02 09:15:00  921.150024  923.250000  920.200012  921.250000
# 2023-11-02 09:30:00  921.450012  924.599976  920.500000  923.650024
# 2023-11-02 09:45:00  923.599976  923.700012  921.099976  922.400024
# 2023-11-02 10:00:00  922.400024  923.099976  920.299988  920.849976
# 2023-11-02 10:15:00  920.849976  922.099976  920.250000  921.650024
# ...                         ...         ...         ...         ...
# 2023-11-10 14:15:00  936.849976  937.400024  935.400024  936.700012
# 2023-11-10 14:30:00  937.099976  938.200012  934.849976  936.849976
# 2023-11-10 14:45:00  936.700012  937.750000  936.099976  937.700012
# 2023-11-10 15:00:00  937.700012  939.750000  937.049988  938.500000
# 2023-11-10 15:15:00  938.500000  941.099976  937.400024  938.599976
#
#                       Adj Close  Volume
# Datetime
# 2023-11-02 09:15:00  921.250000  260161
# 2023-11-02 09:30:00  923.650024  381597
# ...
